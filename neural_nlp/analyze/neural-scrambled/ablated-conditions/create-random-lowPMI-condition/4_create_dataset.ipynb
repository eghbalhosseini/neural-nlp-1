# %%
import pickle
import os

from neural_nlp.benchmarks.neural import *
from neural_nlp.models import *
import neural_nlp
from neural_nlp.models.implementations import *
from neural_nlp.stimuli import StimulusSet
import xarray as xr

benchmark_pool = [
    # primary benchmarks
    ('Pereira2018-encoding', PereiraEncoding),
    ('Fedorenko2016v3-encoding', Fedorenko2016V3Encoding),
    ('Blank2014fROI-encoding', Blank2014fROIEncoding),
    # secondary benchmarks
    ('Pereira2018-rdm', PereiraRDM),
    ('Fedorenko2016v3-rdm', Fedorenko2016V3RDM),
    ('Fedorenko2016v3nonlang-encoding', Fedorenko2016V3NonLangEncoding),
    ('Blank2014fROI-rdm', Blank2014fROIRDM),
]
benchmark_pool = {identifier: LazyLoad(lambda identifier=identifier, ctr=ctr: ctr(identifier=identifier))
                  for identifier, ctr in benchmark_pool}

# how to fetch stimulus set
benchmark_test = benchmark_pool['Pereira2018-encoding']
stimuli_df = benchmark_test._target_assembly.attrs['stimulus_set']
stimuli_df
# Out:
#                                               sentence  sentence_num  \
# 0    Beekeeping encourages the conservation of loca...             0
# 1    It is in every beekeeper's interest to conserv...             1
# 2    As a passive form of agriculture, it does not ...             2
# 3    Beekeepers also discourage the use of pesticid...             3
# 4    Artisanal beekeepers go to extremes for their ...             4
# ..                                                 ...           ...
# 622  Some windows have multiple panes to increase i...           379
# 623                   A woman is a female human adult.           380
# 624    A woman is stereotypically seen as a caregiver.           381
# 625     A woman can become pregnant and bear children.           382
# 626  A woman has different reproductive organs than...           383
#
#           stimulus_id    experiment                       story  \
# 0      243sentences.0  243sentences     243sentences.beekeeping
# 1      243sentences.1  243sentences     243sentences.beekeeping
# 2      243sentences.2  243sentences     243sentences.beekeeping
# 3      243sentences.3  243sentences     243sentences.beekeeping
# 4      243sentences.4  243sentences     243sentences.beekeeping
# ..                ...           ...                         ...
# 622  384sentences.379  384sentences  384sentences.building_part
# 623  384sentences.380  384sentences          384sentences.human
# 624  384sentences.381  384sentences          384sentences.human
# 625  384sentences.382  384sentences          384sentences.human
# 626  384sentences.383  384sentences          384sentences.human
#
#      passage_index passage_label passage_category
# 0                1    beekeeping       beekeeping
# 1                1    beekeeping       beekeeping
# 2                1    beekeeping       beekeeping
# 3                1    beekeeping       beekeeping
# 4                2    beekeeping       beekeeping
# ..             ...           ...              ...
# 622             95        Window    building_part
# 623             96         Woman            human
# 624             96         Woman            human
# 625             96         Woman            human
# 626             96         Woman            human
#
# [627 rows x 8 columns]

# %%
#load perturbed dataset
with open("stimuli_within_sent_random_lowPMI.pkl", "rb") as f:
    random_lowPMI_df = pickle.load(f)
random_lowPMI_df
# Out:
#            stimulus_id                  condition  \
# 0       243sentences.0  within_sent_random_lowPMI
# 12      243sentences.1  within_sent_random_lowPMI
# 27      243sentences.2  within_sent_random_lowPMI
# 30      243sentences.3  within_sent_random_lowPMI
# 47      243sentences.4  within_sent_random_lowPMI
# ...                ...                        ...
# 6221  384sentences.379  within_sent_random_lowPMI
# 6234  384sentences.380  within_sent_random_lowPMI
# 6246  384sentences.381  within_sent_random_lowPMI
# 6253  384sentences.382  within_sent_random_lowPMI
# 6266  384sentences.383  within_sent_random_lowPMI
#
#                                                stimulus
# 0     habitats conservation encourages the beekeepin...
# 12    to produce interest it plants every pollen is ...
# 27    that crops agriculture a of for form not way t...
# 30    kill also beekeepers the discourage of use cro...
# 47    product is go for artisanal but the to craft b...
# ...                                                 ...
# 6221  multiple to inside windows some have insulatio...
# 6234                    female a a is human adult woman
# 6246     stereotypically caregiver as is woman a seen a
# 6253      a pregnant and children can become bear woman
# 6266  different a woman reproductive a has than orga...
#
# [627 rows x 3 columns]

# %%
random_lowPMI_stimuli = list(random_lowPMI_df['stimulus'])
random_lowPMI_stimuli
# Out:
# ['habitats conservation encourages the beekeeping of local',
#  "to produce interest it plants every pollen is local conserve in that beekeeper's",
#  'that crops agriculture a of for form not way to vegetation native cleared make does as require be passive it',
#  'kill also beekeepers the discourage of use crops the on they pesticides could honeybees because',
#  'product is go for artisanal but the to craft beekeepers extremes effort their their worth',
#  'artisanal and and over honey-making quality emphasizes quantity character consistency',
#  'micromanagers become produce of honey to finest the their honeybees beekeepers',
#  'select the best extract and flows to when scout ways know honey nectar fields they the',
#  'hive fills as of the 40000 the beekeeper opens air bees deep the the hum',
#  'pollen honey nursery supplies beekeeper bee and checks the stores the',
#  "and across they're arms sting hands they but because bees don't bare his crawl gentle",
#  "i'm no about college have longer dream though recurring i exams in a even",
#  "my exam realize dream the my i've never suddenly and class to it's gone day i of in final",
#  "reading even assignments i've the never done any of",
#  'have people nightmare same other know who i the many',
#  'experience morning had study write the to dream night from in each participants the their down previous',
#  'dreams recalled intensity if each recorded and any and they described dream emotional its they',
#  'participants bad each then assigned a a or to flying such category nightmare dream dream a dream as a',
#  'when sleep are as night our are while every awake we minds as we active',
#  'ninety the we cycles in of about night throughout minutes each dream',
#  'can fill our strange of and and combinations dreams places stories feelings characters images',
#  'things when decided cards bad start to to i playing from worse went',
#  'i had doing and do had $10000 spent already i it to close to gambling was something',
#  'me my friends were away sick of gamble savings watching my',
#  'was after a the money not part leaving have i did the losing hardest of casino horror',
#  'on to economic legalized data by come the effects are and social good hard gambling of',
#  'a indicate problems likely gambling casino some studies more makes that nearby having',
#  'also gambling marriage and associated personal with may be problems bankruptcies',
#  'the expansion been generation of past over dramatic gambling has a there legalized',
#  'casinos states and instituted lotteries have well have many most as',
#  'business become controversial very but gambling has big',
#  'a wind in house kitchen from the shattering the hurricane the the shook window',
#  'ran door surrendered some hurricane the grabbed the slammed food to we and kitchen in the',
#  'house ripped be afraid its our foundation i from was would',
#  'fell night later with that shaking the the huddled the we house asleep sofa wind on',
#  'can off off and their foundations houses trees suck of hurricanes limbs tear',
#  'dump rains mudslides floods they trigger that and heavy can',
#  'a water that a bring ocean surge of can hurricanes storm onto also land wall lurches',
#  'several evidence scientists methods to hurricanes use for look of ancient',
#  'the strongest coastal at of windblown the of lakes deposited beach sand layers storms bottoms',
#  'by drenched record growth hurricanes preserve storm their rings trees of a passing in each',
#  'is world different different american the exported ice preferences countries have cream around but',
#  'ice enjoy people many cream delicacies local their flavored with',
#  'tropical fresh cream topped and mangos vanilla some is places ice bananas with in',
#  'making at cream i a as ice remember child home',
#  'tub it cream start a then the we the cold the into turning to mixture crank frozen expose to poured',
#  "eventually i couldn't the hand enough turn more it froze crank that any",
#  'the harden cream put of into half-frozen then the freezer to i ice container',
#  'half flavorings and is cream to milk mixture ice up or sugar cream air whipped-in a of',
#  'what the butterfat smooth cream is and and in it makes silky milk',
#  'cream premium is natural high-priced ice butterfat and loaded flavorings with',
#  'chair use mower my the hurt i uncomfortable lawn makes the when back riding',
#  'use control i two front machine the to me the levers of in',
#  'grass sharp sever underneath of the mower the blade each lawn blades precisely',
#  'long task a taught patience mowing and has is me the lawn it',
#  'cut grass that a a an mower machine to is height even lawn revolving blades with',
#  'motor muscle or have the machine blades by the may a may powered be',
#  'the mowers is small source power for engine most common lawn a gas',
#  'the for they create not emissions because environment do electric lawnmowers are better',
#  'and they less less to also expensive maintenance run are need',
#  'an as lawn toaster use electric as mowers much electricity ordinary',
#  'for long astronauts a their spacewalks time train',
#  'much underwater conducted their of training is',
#  '10 every to floating pool hour will in in may they they the space 8 hours for spend spend',
#  'outside able on perform practice repair the and the construction to work space astronauts be station to of',
#  'test many flights commanders always and pilots as of are the military backgrounds shuttle have pilots',
#  'engineers run astronauts doctors in experiments as and who are scientists can other trained space',
#  'diverse were men now early crews much but more young all astronauts are',
#  'exterior shuttle the floated the to out astronauts together of team the of space',
#  'telescope on part they broken repair to the the needed carried tools huge',
#  'bolts the while the the part the loosened astronaut other place fitted one on replacement pipe into',
#  'by in used long computers a been experimental for art have time artists',
#  'and art entered widespread affordable the are have mainstream computers world computer now more that graphics',
#  'some technology science have showcase computer graphics the exhibitions that art conferences latest',
#  'have cultures to two up are that conferences new bridging sprung devoted the brand',
#  'graphics procedures doctors works visualize computer conditions to medical and the surgical specialist with',
#  "structures uses animation to doctors a patient's body she understand help within digital",
#  'an at screen structures is in much than internal a x-rays on seeing animation clearer the squinting',
#  'tool digital powerful is for animation a modern education',
#  'help graphics the as field ask broadens actually computer of if must we graphics students',
#  'does and digital classroom can vivid in research the that be suggest engaging imagery effective',
#  'reason first school to was came place the the law he cliche in',
#  'wanted better change the things he to for',
#  'pulled school at the all-nighter director one he he an evening program when had recalled law and',
#  'drafting several evicted families they at petition for finally sunrise a finished',
#  'education the past has legal up four cost the relentlessly decades gone over of',
#  'by the school 1970s private four factor increased since law a of tuition',
#  'eventually lawyers new admission crash could school the for for law and market to',
#  'law law minimal faculty actually often school in have experience practicing',
#  'journals articles prestigious law on for review professors focus writing',
#  'on feudal schools property in topics with theoretical often law law emphasize the classes england like',
#  'increasingly preventive involved in pharmacists care are',
#  'people because advisers pharmacies are health go becoming they front-line to often',
#  'about public of are a information good often source pharmacists health',
#  'know consult because lot effects drug side doctors pharmacists about with they and a interactions',
#  'to the about of safe pharmacists offer prescription patients dispense and use medications advice drugs',
#  'screenings also provide and and health they vaccines conduct wellness',
#  'have two pass professional in licensed and to order degrees must pharmacists exams be',
#  'as chose pharmacist think to profession chose i as the a much me be pharmacy i',
#  'neatly child bottles in by as the a pharmacies fascinated arranged was i',
#  "the it's know but love cliche have impact i i patients lives my that i on of",
#  'potentially her person to or situations has each response his stressful own',
#  'person by may while stressful one unemployment may fulltime devastated another be working find',
#  'are everyday like there being in traffic stresses stuck',
#  'of divorce are a child also there traumatic such loss stresses or as',
#  'people of can stress different some adapt levels to',
#  'stress health dealt a though not with toll take if effectively real can on',
#  "stress to that harmful beneficial it your remember it's be reaction will if that determines or",
#  'company worried stressed my downsizing i and was when incredibly felt',
#  'race for dizzy i reason heart at even no would my and felt times',
#  'manage then yoga i to to taking stress my level started try',
#  'jet satin tuxedo the with man wore stripes black a',
#  'latest made cut rich style with was in the fabric it',
#  'man he it fit as tailored had clearly it perfectly the',
#  'professional out would have something formal looked picked for like stylist event it a a',
#  "still grooms the statements personal making tuxedo preferred are is attire today's while in wedding",
#  'the fashion shorter of wedding on cutting jackets are men edge for',
#  'tuxedos shirts up also colorful their grooms and satin are jazzing with ties',
#  'silk jacket a with black tuxedo tailless a is jacket dinner lapels',
#  'a black perfect should the to jacket trousers tie be tuxedo match',
#  'the jacket match and should and plain black should be white the be the shirt lapels always tie',
#  'pianist went adulthood in blind the concert',
#  'her slowly was genetic blindness by eyes the condition a damaged that caused',
#  'told that advantage a she blind to interviewers being an was pianist',
#  'she concentrate had so music visual her she more no on fully could distractions',
#  'for the vision activities life defines insufficient as of blindness the ordinary government',
#  'blind resources by legal legally the parameters focused establishing of the can on be blindness',
#  'have this vision who who overlook do but meet may standard not those problems the',
#  'countries in disease by blindness is children and in usually infectious caused deficiencies nutritional developing',
#  'supplements be causes by can and often prevented these vitamin medicine',
#  'developed caused likely to genetic countries in is more by blindness be problems',
#  'no one exactly your brain to taste really mouth how from gets knows your a',
#  'process the a molecule a think bud touches of begins food when scientists cell taste',
#  'carries a taste beneath message cell cell nerves to the taste the',
#  'once bud to of it the basic one taste responded believed that each tastes was four',
#  'of on only is you tip sweet something taste the a were if the that tongue respond eating bud would',
#  'sensitive now single a to all bud basic can of the think taste that scientists be tastes',
#  "sense isn't my eat good of strong foods with very flavors to so i very tend taste",
#  "of sauce coffee i like no very so drink with bitter i it's hot and lots cream my",
#  "so cookies extra add can't i when sweetness taste i i even well sugar make",
#  'real hip problem are aging for fractures a individuals',
#  'the difficult of with and are healing process pain faced break the of the patients',
#  "loss the adjust have independence patient's to of to families",
#  'fractures substantial hospital and for hip and involve society in time the expense',
#  'heard snapping halfway the like a fingers race someone sound i through their',
#  'and that my foot i instantly a knew i felt broken was crunch',
#  'running every on felt spikes like step',
#  "the at office clearly x-ray fracture the the doctor's afterward showed",
#  'are types a few bone different fracture of there',
#  'broken the fractures but the is simple skin bone closed or is intact in',
#  'the compound and broken punctured or an in the has skin fractures bone open wound produced open',
#  "not ear new cleaned become infected piercings if can they're carefully",
#  'around the infection or tenderness redness earlobe signs of swelling include',
#  'if these clean ointment the some area you and see symptoms apply',
#  "provider if the health your don't redness away care contact and swelling go",
#  'to hospital new initiated has local infections reduce a measures',
#  'infected improved are hand that from patients have and ensured patients habits isolated washing other they',
#  'since began rates measures hospital the has infection drop new seen the',
#  'wound scrubbing delays increases which a the soap risk with infection healing alcohol or of',
#  'band-aids heat infection moisture in can risk and holding by of the increase',
#  'can be easily fortunately infections they are most once skin treated diagnosed',
#  'sixteenth end modern of opera started at the century the',
#  'and to it an effort as rediscover imitate began tragic performance greek',
#  'their antiquity subject early tales for matter founders of chose opera from',
#  'traditions different out branched operas stories into sources of later and musical',
#  'music that singers in words and form is a and play perform opera art combines which an musicians',
#  'acting such spoken the incorporates of costumes theatre it of elements and scenery as many',
#  'opera orchestra typically accompanied given an and house are by an performances in',
#  'has opera the the role the win production hard worked new singer in to',
#  'just her not job about singing is',
#  'critical presence all acting and interpretation musical stage are',
#  'certainly star voice pure but of show the the her strong is',
#  'must in a a while painting completing keep elements many painter mind',
#  'and solid like has design composition to she lighting strong elements of use',
#  'the skill she brush execute with has to strokes',
#  "a most the content the the painter's of reveal importantly of painting should glimpse soul",
#  'painters creative employed artisans than long as skilled artists as ago more were',
#  'and court of the prominent however had status the members of scholars painters royal social',
#  'their their subject on a they personal patrons its and signed with established imagery and work decided relationship',
#  'to the on painting i on the and actual as focus learned painter scene itself less more a',
#  "artist's that within eye of not is camera a to has lens vision an everything its field record",
#  'but more useful needed painting i than good is provides for a nature found information',
#  'impressive owl eagle the is bird an',
#  'ear like has stick horns up tufts it that',
#  'they pierce right creepy you orange through like are eyes downright could and large look its',
#  'this hunts flying swiftly at the night and silently darkness owl through',
#  'species while become are have owl others endangered some thriving',
#  'well owl previous beyond its has spread barred the habitat',
#  "early findings facilitated that may logging owl's invasion suggest have the barred",
#  'branch talons landed her a owl it thick the on and with gripped',
#  'eye wings settled pressed half-closing she to and sides down her an her',
#  'for of have she eyes been glow might her statue a the but',
#  "floating unnerving watch a bear across sea to it's stalk ice polar",
#  "beneath in when frigid even the it's huge directly the submerged waters you animal are worse",
#  'paws polar set overhead down the its the as ice giant prey bear on pursued',
#  'crew i shots as capturing film months polar spent documentary for a bear the part of these',
#  'people polar than the or of for attack other confusion reasons will animals one fear bears few that are',
#  'may environment live a attack they out they food-scarce hunger of in because',
#  'up to sneak slowly people their energy they careful on conserve will',
#  "bear's an diet seal part polar is the the of important",
#  "when are on ice will seals stalk or that breathing a hole they seal's basking wait the hunting by",
#  'the crawl bear quietly place seal freeze around in looks when polar the will and forward',
#  'not castle a structure for was the defense built primarily medieval',
#  'its its to was surroundings dominate purpose',
#  "walk castle a day's easily lands control within a could",
#  "protection inside peasants attack brought property walls of castle's could and times livestock be the for during",
#  'stormy in castles dramatic of the locations history provide record many of a regions spectacular',
#  'cliffs beautiful and stand quaint rocky villages they today atop overlooking landscapes',
#  'and home were they intrigue the past to battles plots in',
#  'a a looming leaving saw we magnificent station on above built upon train cliff hotel our the castle',
#  'walls the outside feet river sheltered an courtyard the of hundreds inner above thick',
#  'incredible but tower our an view had scary slightly rooms',
#  'feet small side the a me the climbing after pyramid gestured entranceway man up of fifty black into the',
#  "center chamber at into pyramid's led the the this",
#  'steep dark narrow him followed the passage down i',
#  'the the the thick chalky was air and smell was pyramid inside',
#  'the more just the the pyramids of represented the king pride of tomb nation than',
#  'in their is the builders took the that craft evident care pyramid',
#  'fitted precisely polished pyramid until gleamed stones were structure the the covering together the and',
#  'of still constructed how mysteries the to architects are were working pyramids solve',
#  "the blocks raise think walls built ramps pyramid's were some inside stone to",
#  'ramps speculate the the zigzagged of exterior pyramid that others up walls',
#  'takes and climbing even beginner courage strength rock',
#  'learning large climbers on who the sport boulders are scrambling try can',
#  "ropes they're they that begin climb safely faces using can comfortable rock to vertical with once",
#  'boys the on to all were trip rock of the new climbing',
#  'of many afraid were heights',
#  'knots someone helped and down check else having calm harnesses their them',
#  'set climbing beginners adults appropriate routes for the up',
#  'is rock one of free-climbing style particular climbing',
#  'skill relies the her rock and on face ascend physical climber a solely to strength',
#  'rope equipment only bolts are and the used',
#  'falls the they she only to meant climber are stop if',
#  'me buddies convinced steep skied my hesitantly trail that to try down the i',
#  'myself tumbling i and made down turn i a found bad',
#  'stop slope a to a i the part finally flat at of came',
#  'snow my poles be drift were the in a up and nowhere to my skis hill lodged found were',
#  'ski a how strength skiers use they of major poles is professional',
#  'and use balance proper skiing their of to their ski adds flair improves poles',
#  'movements for regain it upper body lost while need balance skiing minimizes the to',
#  'ski new turn stiffer and designs let more skiers boots quickly',
#  'turns the and the twisting but increase force legs faster on tighter',
#  "particularly has to ligaments to more the skier's in knee this injuries led",
#  'portable an musical two accordion with is a instrument keyboards',
#  'keyboard notes used for one other chords is for individual the',
#  'that blow with through sound produce accordions bellows air reeds',
#  'the keyboards accordionist both opening plays closing bellows while an and',
#  'is apartment that home part building self-contained a of a is an',
#  'kitchen or as have one bathroom as more rooms and apartment well may a a an',
#  'some are for single people others apartments for families',
#  'space have garage the storage can or a building a laundry facility extra',
#  'green a apple that an be yellow fruit can or red is',
#  'pulp apples a skin and crisp seeds thin inside sweet have',
#  'cider very are make apples to some used tart',
#  'can roasted or pies in eaten be raw baked apples',
#  'or criminal burning wildland of act the is building arson a',
#  'fire was a fire arson accident or determines a investigation caused if by',
#  'cause be or collect done can to arson insurance to others damage',
#  'of harmed the depends people were whether crime the severity on',
#  'transporting a an wheeled for is automobile car passengers or vehicle',
#  'engine a by a be gasoline powered electric can or car',
#  'other car roads just steers on the sit the passengers driver',
#  'of of automobiles vary number size trunk type in and doors the',
#  'wood a axe tool and is to the cut split used',
#  'a consists attached axe a head usually handle to of the',
#  'were axe then of made historically and metal stone heads',
#  'and used axes entering firemen buildings woodcutters are by',
#  'a edible inside grows long is with soft in a bunchs banana a fruit that',
#  'and have yellow be red banana spots a when ripe or small can purple brown',
#  'producers india such countries the are ecuador tropical or as greatest',
#  'potatoes plantains bananas often staple and cooked and foods unripe are like',
#  'to in have place as piece sleep or bed of is sex a a a furniture used',
#  'and sheets box a spring plus a and made a covers bed of is mattress pillows',
#  'air water airbeds the filled filled and in it with waterbeds with is is in mattress',
#  'type hammock above the bed is fabric sling the of a another suspended ground',
#  'a insect and black bee a legs a body flying is with and yellow six',
#  'honey make spread as nectar flowers between they to collect bees pollen',
#  'are hive in colony social a located a live and together insects bees in',
#  'they bees if many feel have attack and threatened stingers can',
#  'bicycle and frame is on two vehicle pedals a a a with wheels',
#  'pedalling is saddle of bicycle cyclist propelled the a the on by a',
#  'an inner rubber full air have with the tube of wheels tires',
#  'racing recreation transportation people use for and bicycles',
#  'blacksmith objects iron steel creates a by or forging',
#  'and an shape hammers its a iron anvil on to hot bends change blacksmith',
#  'apron handle with tongs blacksmiths thick a and wears the metal',
#  'weapons blacksmiths like shoes furniture horse objects make or iron',
#  'used kitchen or mix puree to a a is blender ingredients food appliance',
#  'blade or glass with a a bottom blenders plastic container in have the rotating',
#  'milk fruit to are blenders and shakes make smoothies used',
#  'with also ice alcoholic are crushed cold make to blenders drinks used',
#  'has young is child male undergone a not who a puberty boy',
#  'used the is indicate relative distinctions sex to to term girls',
#  'fight play rough each other traditionally to games like with and boys',
#  'adult as boy is male to often immaturely a an behaving referred',
#  'cabbage the is a family broccoli in plant',
#  'thick flower green and has a tough head stalk a broccoli',
#  'nutrients vitamins is high and broccoli in fiber other',
#  'or raw can stir-fried boiled broccoli be eaten',
#  'flying with a a insect four large butterfly is wings',
#  'can butterflies patterned very of and wings be colorful the',
#  'transformation is butterfly metamorphosis into of the a caterpillar a',
#  'wings because people some butterflies their colorful of collect',
#  'laborer or carpenter wood is artist works who a an manual with',
#  'objects other houses carpenters boats furniture repair and and build',
#  'saws hammers carpenters pliers tools such and planes use as',
#  'makes musical is carpenter and instruments repairs that a a luthier',
#  'legs furry with a four and tail are cats animals small',
#  'themselves cats fur to groom their licking by like',
#  'fed hunt but are can or owners by their often mice cats birds',
#  'that retractable sharp keep cats are the so claws they of',
#  'sit designed furniture a is on of chair to for people a piece',
#  'seat level supported a chairs of by raised above consist legs floor',
#  'have well as cushion and arm can back a also chairs rests as',
#  'vehicles seats places located chairs in like are in or fixed cinemas',
#  'musical a a clarinet instrument is woodwind',
#  'bottom flare at is black long with clarinet a tube a a the',
#  'holes keys by chooses the notes pressing player and',
#  'music used clarinet the classical is and in jazz both',
#  'a colder the atlantic fish in areas is lives of a cod the that',
#  'cod easily and white flesh when and is flakes cooked mild-tasting',
#  'used fresh salted chips for dishes for cod and fish elaborate is cod',
#  'has and the of since been the vikings cod time caught traded salted',
#  'coffee from coffee the seeds coffee plant is the of beans made',
#  'drink a countries in hot and served popular is many coffee usually',
#  'drug that mild a called awake caffeine contains coffee people keeps',
#  "export is world's the coffee seventh-largest agricultural legal",
#  'almost natural where falls a a no is environment desert rain',
#  'filled sand usually or are deserts rocks dunes with hot',
#  'some in adapted animals live have and deserts plants to',
#  'is the biggest hot sahara northern the in africa desert',
#  'furniture desk with sometimes for at a working a used a of is computer piece',
#  'made metal a and or a has of flat can plastic wood desk be surface',
#  'and papers may to drawers a supplies have store desk',
#  'by a desk three surrounded a of cubicle consists sides on partitions',
#  'exit a barrier door an is from movable to area a or enclosed entrance',
#  'pass gets doors most have who them control through locks to to',
#  'pulling after a doors handle most pushing opened they are or by unlocked are',
#  'chamber of types can revolving slide other of or a doors consist',
#  'wear is dress of piece clothing a a women that sometimes',
#  'to shirt a a skirt a matching dress attached is like long',
#  'is dress as dance or usually such wedding formal worn a a occasions at a',
#  'stairs it be a a bike can or to hard in dress climb ride',
#  'driving effects alcohol the the act under drunk of is of driving',
#  'most the vehicle in crime world of drunk of any is driving a',
#  'almost deaths vehicle-related role a of it in half all plays',
#  'tests caught by drivers breathing field sobriety drunk are and',
#  'lack rain shortage by the persistent of water is of a caused drought supply a',
#  'plants to crops stop cause and die drought growing and will',
#  'eventually areas drought extreme cause into turn famine desert and will',
#  'away to bowls of people large from dust have migrate numbers',
#  'are the birds day of have large eyesight hunt that very during prey and eagles good',
#  'hooked sharp and flesh beaks talons for legs have strong eagles tearing',
#  'fish eagles mammals small others in species and eyries eat and live some',
#  'is bright bald united the the white has national head eagle of a and the bird states',
#  'and structures other ground down can and buildings shake the knock earthquakes',
#  'the trigger can volcanic and shaking landslides activity also',
#  "in release caused the earth's the most by energy crust are earthquakes of",
#  'at sea earthquake the can and tsunami an displace seabed a cause',
#  'land weighing of are mammal elephants largest tons kind the several',
#  'elephant which a nose a things an long called grab trunk can has or food',
#  'into of has objects for trees or ivory elephant the pair digging a tusks moving',
#  'elephant and large the the to its them cool its body flaps in blood ears',
#  'light sensing coding organ cortex and an the the it visual is for for eye',
#  'and complex motion can have most texture detect animals eyes which color',
#  'of of the is sensitive part center human the and it fovea eye most the the',
#  'insects eyes facing in eye have many units up compound of made directions',
#  'plants used land or raise grow is a farm animals to for food',
#  'produce farmers the people the and run decide are farm what to who',
#  'for barn and a have a farms a house usually silo farmers',
#  'farm many farmers the a share cooperative and is where equipment a land',
#  'fingers have on thumb and each primates usually a hand four',
#  'and grasping other are writing grooming for activities fingers used',
#  'fingertips are pressure temperature vibration to the and sensitive',
#  'tip the the the grown or and finger can nail decorated of protects be',
#  'an land of an of that inhabited is water a expanse submerges overflow flood',
#  'earthquakes snow rapid flood at well melt caused or heavy as by be as sea can rain',
#  'break dams river in a its out will a channel of levees and or flow flood',
#  'a during diseases water the causes evacuate contaminated people flood and',
#  'a horizontal inside floor for a used surface a building on is walking',
#  'bare tile wooden be concrete made floorboards may of or floors linoleum',
#  'dampen comfort floor often a and people to put carpets noise for on',
#  'under the buildings has floor and electrical it often pipes in wiring',
#  'foot a body end leg a part the of a on is',
#  'running walking use people straight feet or when standing their',
#  'both use sports and people kick feet also fighting to their in',
#  'for related have many feet rules behavior cultures to',
#  'of is trees density an a canopy cover area high and a forest with',
#  'the of depends location rainfall its type in and on temperature forest',
#  'as has various as well trees animals ecosystem plants types a ground forest and of',
#  'the forests down of is regeneration disregarding cutting deforestation',
#  'with is for several a fork tool and solid eating a tines a foods handle',
#  'disposable forks metal made if of or usually plastic are',
#  'to while in hold to are place food forks cutting to or food the lift mouth used',
#  'western forks used foods cultures for there special kinds are and are various in',
#  'frying sloping is small pan with a a pan and handle sides a',
#  'brown frying is and a fry used sear pan to food',
#  'covering cooked the the the oil bottom food of pan is on',
#  'are frying iron steel made teflon-clad of or pans',
#  'is female reached human girl who not yet a maturity has a',
#  'develops at of a girl that puberty body into woman the a of',
#  'girls and like with games social often dolls playing',
#  'girls skirts sometimes hair dresses wear and long and grow',
#  'glove the is piece clothing covers of a fingers a hand and that',
#  'material or made wool lined cold against to of protect gloves are waterproof',
#  'or are latex from shield used disposable rubber hands germs gloves chemicals to or',
#  'a fingers is are where glove mitten four together kind covered of a the',
#  'an an a tool deliver used impact to to a is object hammer',
#  'into wood most hammer to drive often is nails a used',
#  'to nails the remove be head claw on used the can',
#  'the of vary the and handle head length in hammers shape',
#  'used explosive a against hand as people a grenade weapon an is',
#  'hand and after timed to grenades are a that explode thrown bit',
#  'can launchers fired shoulder from also or rifles grenades be',
#  'of a tear disperse thrown middle gas mob grenades are into it the to',
#  'a horse mammal legs large is long a with muscular hoofed four',
#  'a neck a tail usually gray and and on mane brown is or has its horse a',
#  'for used and horses travel have work entertainment draft been',
#  'trots or a it human ride a horse walks can while gallops',
#  'are go when people be to injured sick hospitals they to or healed',
#  'staffed surgeons and professional physicians are hospitals nurses by',
#  'some specialist there leaving same for day diagnosis patients go therapy or the',
#  'some weeks operations stay have treatments for for patients several to or',
#  'building structure or for house a or people a families is to in permanent live',
#  'roof let keep out light rain house windows a cold has and and to walls to and in a',
#  'house for or purposes can a sleeping rooms have cooking washing like',
#  'back and work leave house night come sleep eat the to to and people at most',
#  'snow a an of by shelter inuit is made blocks from of type igloo',
#  'the are in where snow covers land the igloos time of places built most',
#  'the shape igloos tunnel often entrance in with a dome are of built an',
#  'warms body pockets igloos air in the and heat space snow insulate',
#  'things sharp is used is cut edge tool a to a with a that knife',
#  'usually knives a handle and consist a modern metal made blade of of',
#  'in and also used have as instruments weapons knives rituals been',
#  'can attack knife by throwing to stabbing used slashing a be or',
#  'seeds family the a of are the lentils of legume plant',
#  'green lentils or can red black yellow brown be',
#  'are in used indian lentils cuisines and commonly mediterranean',
#  'boiling are of cooked great and protein by are lentils source a',
#  'a is climates lettuce a biennial temperate grown often leaf vegetable in plant as',
#  'raw cooked can or other eaten in salads and dishes lettuce be and cold',
#  'a for to grow crop fairly and is suitable easy beginners lettuce considered',
#  'some to taste most leaves are bitterness but bitter the lettuce bred remove',
#  'where and a kept a of is library place a documents books is media collection',
#  'organizing at finding libraries at and and work are experts librarians information',
#  'public go take books to to weeks libraries and people several borrow can for home',
#  'scholarly specialized academic have research and support libraries books',
#  'cabin from round small house built logs a log is a',
#  'frontier of symbol life origins and log a american humble cabin is',
#  'settlers used european were first log by as shelters cabins',
#  'log notch were the built ends logs joints at with cabins using',
#  'adult a a human male is man',
#  'a a through puberty boy man after becomes passing',
#  'with and is manhood masculinity associated virility',
#  'and from men body in women structure height weight differ',
#  'female feed milk a produced mammals to young is by their white liquid',
#  'fed before food can must be solid animals newborn they milk eat',
#  'dairy as milk made and from such products butter cheese are',
#  'liquid and called from produced is soybeans milk coconuts sometimes',
#  'emit a that thin flying small mosquitos sound insects are high-pitched',
#  'have and for the piercing mosquitoes animals plants skin of mouthparts',
#  'bite female protein suck and animals blood and their for mosquitoes people',
#  'diseases bites malaria and fever spread can mosquito other yellow parasite',
#  'mountain above steeply landform that land a surrounding a rises is',
#  'top higher snow sometimes than the hills have at mountains rise and',
#  'a tectonic plate of to forms mountains collision range due',
#  'climb who hike people are mountaineers up mountains or',
#  'we in the we face mouth food cavity put the when eat is',
#  'mix and chew with the it food to teeth saliva has mouth',
#  'and mouth used for talking the also kissing is',
#  'placement speech are mouth tongue in sounds by controlled the',
#  'drinking a sturdy mug a liquids a is with handle for hot cup',
#  'normally of also mug glass is metal be but made or can ceramic a',
#  'insulation a mug for a and ring is thermal thick has base',
#  'imprinted or or have be can plain on mugs drawings them carved',
#  'being with of unlawful murder is human killing intent another the',
#  'of murder it a the victim because serious existence their crime deprives',
#  'or in self-defense not killing murder war is accidentally in considered',
#  'convicted given sentence often penalty the or a a death life is murderer',
#  'orange from orange made liquid drink juice pulp the a in is',
#  'a of acid juice sweet and c lot a contains has orange vitamin taste',
#  'often orange well freshly pulp squeezed as juice contains',
#  'drunk breakfast a orange is from glass often juice at',
#  'and bird parrot warm tropical is that a in lives a regions',
#  'parrots beak a have brightly-colored and sharp curved feathers',
#  'they imitate human it the can repeatedly voice if parrots hear',
#  'and their pets makes popular abilities appearance them',
#  'peach smell is a orange-yellow a characteristic with an fruit',
#  'skin the small is and fine of thin peach a covered in hairs',
#  'stone have peaches inside contains which large red-brown seed the a',
#  'after are and sweet and be peaches must ripening delicate harvested',
#  'musical is means popular played the keyboard a a of instrument piano by',
#  'a key hit vibrating felt-tipped to a causes a steel string hammer pressing piano',
#  'enormous quality an change the the note pedals sound and range piano has to',
#  'solo piano famous is can large concerts repertoire give the pianists and',
#  'live small are american piranhas rivers fish in ferocious south that',
#  'attack schools in most piranhas during day are live and active and the',
#  'are sharp have carnivores teeth very and opportunistic piranhas',
#  'piranhas insects carrion lizards and mammals fish eat',
#  'or that forest fields is raspberry a in the clearings grows fruit',
#  'many consists fruits a of joined small single raspberry together',
#  'with or eaten sugar are into jam by themselves raspberries cooked',
#  'used raspberry are herbal or fresh dried of in teas the leaves',
#  'bird in is that raven thrives climates many black large a a',
#  'insects berries animals ravens on or small carrion feed',
#  'have are and solving of large ravens problem capable brains',
#  'of birds ill-omen and are in tricksters folklore also ravens',
#  'used refrigerator a and preserve is a contain food cooling device to',
#  'a compartment can refrigerators temperature have at small some freezing',
#  'different refrigerator small for types can of compartments a have food shelves and',
#  'magnets white is and refrigerator on its generally often a put people surface',
#  'with a a shoulder rests rifle the that has and twisting firearm a is grooves barrel on',
#  'around rifle spin the fly air make they bullets grooves the as through the the axis',
#  'with scopes rifles shooting in are hunting and sometimes used sports',
#  'can weapon rifles infantry bursts the in assault and are fire standard',
#  'water from to to is salmon ocean that back spawn a fresh the and migrates fish',
#  'high taste protein red content nice has orange and and is a salmon flesh or',
#  'other sushi poaching be or ways salmon in can in by eaten or cooked grilling raw',
#  'also farmed though in can caught most wild salmon the be is common it the fish',
#  'that blade a cut a hard tool materials wire is hard abrasive or saw to a uses',
#  'the small the along cutting side teeth of points called saw the are the sharp',
#  'hand gas by worked motor by engine saws electric be or or powered an can',
#  'extensively medicine forestry saws carpentry in construction are and used',
#  'scientist and new physical produces studies about world the a knowledge',
#  'a to and experiments creates does hypotheses scientist them test',
#  'and of classic chemistry are biology examples physics sciences',
#  'conferences journals publish scientists in and their research',
#  'cutting are instrument for scissors two-bladed a used',
#  'metallic metal are plastic blades the with usually handles or',
#  'depending scissors the and format can fabric hair on size or paper cut',
#  'shears of or pieces shrubs used scissors are large metal cutting for',
#  'tightening screwdriver inserting is something screws a a and tool for into',
#  'also to can screws after be screwdrivers are inserted used they remove',
#  'handle the rotating screwdriver applies the the from torque tip',
#  'screwdrivers and major types are phillips of the two flathead',
#  'a large a cartilage skeleton fish is with a shark',
#  'bodies sharks large dorsal have streamlined with fin a',
#  'jaws most sharks with on fish predate and powerful mammals',
#  'electrical very and have senses can sharks fields keen detect',
#  'ship water vehicle a a travels and is on large floats that',
#  'the ship sails in engines can by or powered be a steam ocean diesel',
#  'in ocean to the fish transport used cargo are to and containers ships',
#  'people that floating cruise hotels between cities take are ships',
#  'for is heel sole a an a clothing foot a shoe outsole the and with',
#  'rubber leather made canvas usually are or shoes plastic of',
#  "high many and in and have styles colors women's come shoes often heels",
#  'shoe and is sports a for sneaker athletic activity a',
#  'the member armed forces who a a fights of national is land on soldier',
#  'the soldier in camouflage wear militia a a must uniform usually',
#  'a in paid his soldier for or army is a her volunteer work',
#  'rifles as weapons a fights grenades such and using soldier',
#  'end are of spears weapons one head that sharpened at and a consist pole',
#  'the before common personal spears were of the weapon firearms advent most',
#  'were for spears or in used throwing when fighting stabbing war',
#  'use fishing native people still hunting for some the spear and',
#  'legs insects silk are that with eight make spiders',
#  'to spiders and with use insects webs them build catch silk',
#  'their fangs to use spiders stuck prey paralyse venomous',
#  'a be as as spiders as as or bird small coin can big a',
#  'spongy frequent to low subject swamps land are inundation',
#  'mud covered a water vegetation with and shallow swamp is',
#  'and breeding nesting are for swamps reptiles and birds grounds',
#  'drain produce arable fertile to swamps land often farmers',
#  'on garment the a heavy is for worn warmth torso a sweater',
#  'cotton common but is from sweaters are also often knitted wool',
#  'sweater that called front a opens a the cardigan down is',
#  'collar well sleeve in and as as shape differ cut sweaters decoration',
#  'flat piece is furniture a legs surface and a a table of with',
#  'around for usually to table there are people sit a chairs',
#  'on table to food meal people set a together and cutlery plates a eat',
#  'surfaces used tables work write on or are as also to',
#  'displays a images television appliance that with a an screen is moving',
#  'used films programs or televisions for are watching mostly',
#  'to they console a to used are videogames connected game when play',
#  'or cable broadcast internet received can or via be television content',
#  "property is consent the without of person's their taking theft",
#  'thieves to something receivers or it own to steal sell to',
#  'a theft jail and crime can fines with or be is punishable',
#  'theft industrial intellectual espionage is of and ideas property',
#  'heating toasting kitchen is a for using bread appliance a elements toaster',
#  'it bread done slot and the pop-up in once placed toast eject a toasters',
#  'the and tray toaster on control within have ovens temperature side a door a',
#  'bread like with to or cheese toppings be they allow garlic cooked',
#  'fruit taste red a a tomato and shiny is smooth with the savory',
#  'and more changes from a red softens gets color tomato as to green it ripe',
#  'sauce be salads or tomatoes well make to can as ketchup soup used as',
#  'many varieties with tastes there different sizes of and tomato are',
#  'series connected train that between is track a moves on a stations cars of a',
#  'locomotive train electricity the powered a is or by pulled diesel by',
#  'goods over containers transports long of or freight train fuel distances a',
#  'and between transport suburbs inside stations trains city people a commuter',
#  'passengers is train off where get train or place a on a station a',
#  'train or purchasing for stations have counters machines tickets',
#  'in rooms eat waiting station there places and a to are',
#  'enter next or passengers a cargo from the to trains platform line',
#  'tropical a tropical is over a warm sea formed storm cyclone',
#  'produce and torrential winds can powerful rain cyclones very',
#  'cause tropical coastal can also cyclone and flooding high waves',
#  'move tropical can seriously property inland a damage and cyclone',
#  'with is is played strings the an that four violin instrument with bow a',
#  'violin instrument and in smallest the is highest pitched its family',
#  'chin a the instrument and holds violinist the collarbone between the',
#  'different made bowing one are while the hand neck notes with by fingering',
#  'of vultures animals birds dead on are feeding the carcasses scavenging mostly',
#  'many vultures feathers head a heat have bald without losing for',
#  'use to without wings vultures for miles soar flapping large their',
#  'sick or attack animals the but may kill healthy vultures seldom wounded',
#  'and a an a sometimes solid area protects that defines structure is wall',
#  'rooms into building roof delineate walls divide and space the support the a',
#  'walls usually or well stone brick made drywall as as cement are of',
#  'earth retaining water of stone a barrier provide walls movement or to',
#  'common water 70% of area earth most the liquid on its covering is',
#  'animals people order plants water in must to live drink and',
#  'temperature at and water solid a ice low freezes becomes',
#  'the falls in are is rain vapor from water which clouds sky condensed that',
#  'is a in ocean very mammal that whale lives large the a',
#  'heads breathe through when surfacing on blowholes their whales',
#  'serves the reservoir insulation blubber an energy a whale as and in as',
#  'hunted have oil and whales meat ambergris for whale been',
#  'opening a a wall let a light is in window through transparent to',
#  'place a of held window made by typical sheets in frames is of glass',
#  'open a also when let window sound and through air will',
#  'multiple to inside windows some have insulation increase panes',
#  'female a a is human adult woman',
#  'stereotypically caregiver as is woman a seen a',
#  'a pregnant and children can become bear woman',
#  'different a woman reproductive a has than organs man']

# %%
perturbed_df = stimuli_df.copy()
perturbed_df["sentence"] = random_lowPMI_stimuli

savedir = '/om/user/ckauf/neural-nlp/ressources/scrambled-stimuli-dfs'
fname = f'stimuli_random_lowPMI.pkl'
with open(os.path.join(savedir, fname), 'wb') as fout:
    pickle.dump(perturbed_df, fout)
perturbed_df
# Out:
#                                               sentence  sentence_num  \
# 0    habitats conservation encourages the beekeepin...             0
# 1    to produce interest it plants every pollen is ...             1
# 2    that crops agriculture a of for form not way t...             2
# 3    kill also beekeepers the discourage of use cro...             3
# 4    product is go for artisanal but the to craft b...             4
# ..                                                 ...           ...
# 622  multiple to inside windows some have insulatio...           379
# 623                    female a a is human adult woman           380
# 624     stereotypically caregiver as is woman a seen a           381
# 625      a pregnant and children can become bear woman           382
# 626  different a woman reproductive a has than orga...           383
#
#           stimulus_id    experiment                       story  \
# 0      243sentences.0  243sentences     243sentences.beekeeping
# 1      243sentences.1  243sentences     243sentences.beekeeping
# 2      243sentences.2  243sentences     243sentences.beekeeping
# 3      243sentences.3  243sentences     243sentences.beekeeping
# 4      243sentences.4  243sentences     243sentences.beekeeping
# ..                ...           ...                         ...
# 622  384sentences.379  384sentences  384sentences.building_part
# 623  384sentences.380  384sentences          384sentences.human
# 624  384sentences.381  384sentences          384sentences.human
# 625  384sentences.382  384sentences          384sentences.human
# 626  384sentences.383  384sentences          384sentences.human
#
#      passage_index passage_label passage_category
# 0                1    beekeeping       beekeeping
# 1                1    beekeeping       beekeeping
# 2                1    beekeeping       beekeeping
# 3                1    beekeeping       beekeeping
# 4                2    beekeeping       beekeeping
# ..             ...           ...              ...
# 622             95        Window    building_part
# 623             96         Woman            human
# 624             96         Woman            human
# 625             96         Woman            human
# 626             96         Woman            human
#
# [627 rows x 8 columns]

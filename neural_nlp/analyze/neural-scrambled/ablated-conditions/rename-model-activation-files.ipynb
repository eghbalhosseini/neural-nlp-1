# %% [markdown]
# # Renaming function word files
# ## reason: added ADV to contentword benchmark, should now not be in function word benchmark!
# > keeping the files for plotting for now!

# %%
import os

activations_dir = "/om2/user/ckauf/.result_caching/neural_nlp.models.wrapper.core.ActivationsExtractorHelper._from_sentences_stored"
os.chdir(activations_dir)
print(os.getcwd())
for filename in os.listdir():
    if "functionwords" in filename:
        newname = filename.split(".")[0] + "_OLD.pkl"
        print(filename)
        print(newname)
        os.rename(filename,newname)
# Out:
# /rdma/vast-rdma/vast/cpl/ckauf/.result_caching/neural_nlp.models.wrapper.core.ActivationsExtractorHelper._from_sentences_stored
# identifier=distilgpt2,stimuli_identifier=Pereira2018-functionwords-lasttoken-243sentences1.pkl
# identifier=distilgpt2,stimuli_identifier=Pereira2018-functionwords-lasttoken-243sentences1_OLD.pkl
# identifier=distilgpt2,stimuli_identifier=Pereira2018-functionwords-lasttoken-243sentences10.pkl
# identifier=distilgpt2,stimuli_identifier=Pereira2018-functionwords-lasttoken-243sentences10_OLD.pkl
# identifier=distilgpt2,stimuli_identifier=Pereira2018-functionwords-lasttoken-243sentences11.pkl
# identifier=distilgpt2,stimuli_identifier=Pereira2018-functionwords-lasttoken-243sentences11_OLD.pkl
# identifier=distilgpt2,stimuli_identifier=Pereira2018-functionwords-lasttoken-243sentences12.pkl
# identifier=distilgpt2,stimuli_identifier=Pereira2018-functionwords-lasttoken-243sentences12_OLD.pkl
# ...

# %%
import os

activations_dir = "/om2/user/ckauf/.result_caching/neural_nlp.models.wrapper.core.ActivationsExtractorHelper._from_sentences_stored"
os.chdir(activations_dir)
print(os.getcwd())
for filename in os.listdir():
    if "distilgpt2" in filename:
        if "Pereira2018-2" in filename or "Pereira2018-3" in filename:
            newname = filename.split(".")[0] + "_newPassageGrouping.pkl"
            print(filename)
            print(newname)
            os.rename(filename,newname)
# Out:
# /rdma/vast-rdma/vast/cpl/ckauf/.result_caching/neural_nlp.models.wrapper.core.ActivationsExtractorHelper._from_sentences_stored
# identifier=distilgpt2,stimuli_identifier=Pereira2018-243sentences1.pkl
# identifier=distilgpt2,stimuli_identifier=Pereira2018-243sentences1_newPassageGrouping.pkl
# identifier=distilgpt2,stimuli_identifier=Pereira2018-243sentences10.pkl
# identifier=distilgpt2,stimuli_identifier=Pereira2018-243sentences10_newPassageGrouping.pkl
# identifier=distilgpt2,stimuli_identifier=Pereira2018-243sentences11.pkl
# identifier=distilgpt2,stimuli_identifier=Pereira2018-243sentences11_newPassageGrouping.pkl
# identifier=distilgpt2,stimuli_identifier=Pereira2018-243sentences12.pkl
# identifier=distilgpt2,stimuli_identifier=Pereira2018-243sentences12_newPassageGrouping.pkl
# identifier=distilgpt2,stimuli_identifier=Pereira2018-243sentences13.pkl
# identifier=distilgpt2,stimuli_identifier=Pereira2018-243sentences13_newPassageGrouping.pkl
# ...

# %%
import os

activations_dir = "/om2/user/ckauf/.result_caching/neural_nlp.models.wrapper.core.ActivationsExtractorHelper._from_sentences_stored"
os.chdir(activations_dir)
print(os.getcwd())
for filename in os.listdir():
    if "distilgpt2" in filename:
        #print(filename)
        if "Pereira2018-Original" in filename and not "avgtoken" in filename:
            newname = filename.split(".")[0] + "_newPassageGrouping.pkl"
            print(filename)
            print(newname)
            os.rename(filename,newname)
# Out:
# /rdma/vast-rdma/vast/cpl/ckauf/.result_caching/neural_nlp.models.wrapper.core.ActivationsExtractorHelper._from_sentences_stored
# identifier=distilgpt2,stimuli_identifier=Pereira2018-Original-243sentences1.pkl
# identifier=distilgpt2,stimuli_identifier=Pereira2018-Original-243sentences1_newPassageGrouping.pkl
# identifier=distilgpt2,stimuli_identifier=Pereira2018-Original-243sentences10.pkl
# identifier=distilgpt2,stimuli_identifier=Pereira2018-Original-243sentences10_newPassageGrouping.pkl
# identifier=distilgpt2,stimuli_identifier=Pereira2018-Original-243sentences11.pkl
# identifier=distilgpt2,stimuli_identifier=Pereira2018-Original-243sentences11_newPassageGrouping.pkl
# identifier=distilgpt2,stimuli_identifier=Pereira2018-Original-243sentences12.pkl
# identifier=distilgpt2,stimuli_identifier=Pereira2018-Original-243sentences12_newPassageGrouping.pkl
# identifier=distilgpt2,stimuli_identifier=Pereira2018-Original-243sentences13.pkl
# ...

# %%
import os

activations_dir = "/om2/user/ckauf/.result_caching/neural_nlp.models.wrapper.core.ActivationsExtractorHelper._from_sentences_stored"
os.chdir(activations_dir)
print(os.getcwd())
for filename in os.listdir():
    if "distilgpt2" in filename:
        #print(filename)
        if "Pereira2018-lowPMI" in filename and not "avgtoken" in filename:
            newname = filename.split(".")[0] + "_newPassageGrouping.pkl"
            print(filename)
            print(newname)
            os.rename(filename,newname)
# Out:
# /rdma/vast-rdma/vast/cpl/ckauf/.result_caching/neural_nlp.models.wrapper.core.ActivationsExtractorHelper._from_sentences_stored
# identifier=distilgpt2,stimuli_identifier=Pereira2018-lowPMI-243sentences1.pkl
# identifier=distilgpt2,stimuli_identifier=Pereira2018-lowPMI-243sentences1_newPassageGrouping.pkl
# identifier=distilgpt2,stimuli_identifier=Pereira2018-lowPMI-243sentences10.pkl
# identifier=distilgpt2,stimuli_identifier=Pereira2018-lowPMI-243sentences10_newPassageGrouping.pkl
# identifier=distilgpt2,stimuli_identifier=Pereira2018-lowPMI-243sentences11.pkl
# identifier=distilgpt2,stimuli_identifier=Pereira2018-lowPMI-243sentences11_newPassageGrouping.pkl
# identifier=distilgpt2,stimuli_identifier=Pereira2018-lowPMI-243sentences12.pkl
# identifier=distilgpt2,stimuli_identifier=Pereira2018-lowPMI-243sentences12_newPassageGrouping.pkl
# identifier=distilgpt2,stimuli_identifier=Pereira2018-lowPMI-243sentences13.pkl
# ...

# %%
import os

activations_dir = "/om2/user/ckauf/.result_caching/neural_nlp.models.wrapper.core.ActivationsExtractorHelper._from_sentences_stored"
os.chdir(activations_dir)
print(os.getcwd())
for filename in os.listdir():
    if "gpt2" in filename and not "distil" in filename:
        if "Pereira2018-2" in filename or "Pereira2018-3" in filename:
            newname = filename.split(".")[0] + "_newPassageGrouping.pkl"
            print(filename)
            print(newname)
            os.rename(filename,newname)
# Out:
# /rdma/vast-rdma/vast/cpl/ckauf/.result_caching/neural_nlp.models.wrapper.core.ActivationsExtractorHelper._from_sentences_stored
# identifier=gpt2,stimuli_identifier=Pereira2018-243sentences1.pkl
# identifier=gpt2,stimuli_identifier=Pereira2018-243sentences1_newPassageGrouping.pkl
# identifier=gpt2,stimuli_identifier=Pereira2018-243sentences10.pkl
# identifier=gpt2,stimuli_identifier=Pereira2018-243sentences10_newPassageGrouping.pkl
# identifier=gpt2,stimuli_identifier=Pereira2018-243sentences11.pkl
# identifier=gpt2,stimuli_identifier=Pereira2018-243sentences11_newPassageGrouping.pkl
# identifier=gpt2,stimuli_identifier=Pereira2018-243sentences12.pkl
# identifier=gpt2,stimuli_identifier=Pereira2018-243sentences12_newPassageGrouping.pkl
# identifier=gpt2,stimuli_identifier=Pereira2018-243sentences13.pkl
# identifier=gpt2,stimuli_identifier=Pereira2018-243sentences13_newPassageGrouping.pkl
# identifier=gpt2,stimuli_identifier=Pereira2018-243sentences14.pkl
# ...

# %%
import os

activations_dir = "/om2/user/ckauf/.result_caching/neural_nlp.models.wrapper.core.ActivationsExtractorHelper._from_sentences_stored"
os.chdir(activations_dir)
print(os.getcwd())
for filename in os.listdir():
    if "distilgpt2-avgtoken" in filename:
        #print(filename)
        if "Pereira2018-Original" in filename:
            newname = filename.split(".")[0] + "_newPassageGrouping.pkl"
            print(filename)
            print(newname)
            os.rename(filename,newname)
# Out:
# /rdma/vast-rdma/vast/cpl/ckauf/.result_caching/neural_nlp.models.wrapper.core.ActivationsExtractorHelper._from_sentences_stored
# identifier=distilgpt2-avgtoken,stimuli_identifier=Pereira2018-Original-avgtoken-243sentences1.pkl
# identifier=distilgpt2-avgtoken,stimuli_identifier=Pereira2018-Original-avgtoken-243sentences1_newPassageGrouping.pkl
# identifier=distilgpt2-avgtoken,stimuli_identifier=Pereira2018-Original-avgtoken-243sentences10.pkl
# identifier=distilgpt2-avgtoken,stimuli_identifier=Pereira2018-Original-avgtoken-243sentences10_newPassageGrouping.pkl
# identifier=distilgpt2-avgtoken,stimuli_identifier=Pereira2018-Original-avgtoken-243sentences11.pkl
# identifier=distilgpt2-avgtoken,stimuli_identifier=Pereira2018-Original-avgtoken-243sentences11_newPassageGrouping.pkl
# identifier=distilgpt2-avgtoken,stimuli_identifier=Pereira2018-Original-avgtoken-243sentences12.pkl
# ...

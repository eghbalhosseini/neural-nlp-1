# %%
! python 1a_get_token_surprisals.py --inputf sentence_file_nounsverbs_bypassages.txt --outputf token_surprisals_sentence_file_nounsverbs_bypassages.txt
# Out:
# beekeeping encourages conservation habitats. it beekeeper interest conserve plants produce pollen. form agriculture it require vegetation cleared make way crops. beekeepers discourage use pesticides crops they kill honeybees.
# ['<|endoftext|>', 'Ġbee', 'keeping', 'Ġencourages', 'Ġconservation', 'Ġhabitats', '.', 'Ġit', 'Ġbee', 'keeper', 'Ġinterest', 'Ġconserve', 'Ġplants', 'Ġproduce', 'Ġpollen', '.', 'Ġform', 'Ġagriculture', 'Ġit', 'Ġrequire', 'Ġvegetation', 'Ġcleared', 'Ġmake', 'Ġway', 'Ġcrops', '.', 'Ġbee', 'keepers', 'Ġdiscourage', 'Ġuse', 'Ġpesticides', 'Ġcrops', 'Ġthey', 'Ġkill', 'Ġhoney', 'bees', '.']
# [50256, 20697, 19934, 18656, 14903, 35308, 13, 340, 20697, 13884, 1393, 45075, 6134, 4439, 40362, 13, 1296, 14510, 340, 2421, 28459, 12539, 787, 835, 14450, 13, 20697, 24952, 27518, 779, 27482, 14450, 484, 1494, 12498, 41712, 13]
# <|endoftext|> 50256 None
# Ġbee 20697 tensor([ -7.3203,  -3.7250,  -6.9545,  ..., -17.9763, -18.2337,  -6.2530])
# ...

# %%
! python 1a_get_token_surprisals.py --inputf sentence_file_nounsverbsadj_bypassages.txt --outputf token_surprisals_sentence_file_nounsverbsadj_bypassages.txt
# Out:
# beekeeping encourages conservation local habitats. it beekeeper interest conserve local plants produce pollen. passive form agriculture it require native vegetation cleared make way crops. beekeepers discourage use pesticides crops they kill honeybees.
# ['<|endoftext|>', 'Ġbee', 'keeping', 'Ġencourages', 'Ġconservation', 'Ġlocal', 'Ġhabitats', '.', 'Ġit', 'Ġbee', 'keeper', 'Ġinterest', 'Ġconserve', 'Ġlocal', 'Ġplants', 'Ġproduce', 'Ġpollen', '.', 'Ġpassive', 'Ġform', 'Ġagriculture', 'Ġit', 'Ġrequire', 'Ġnative', 'Ġvegetation', 'Ġcleared', 'Ġmake', 'Ġway', 'Ġcrops', '.', 'Ġbee', 'keepers', 'Ġdiscourage', 'Ġuse', 'Ġpesticides', 'Ġcrops', 'Ġthey', 'Ġkill', 'Ġhoney', 'bees', '.']
# [50256, 20697, 19934, 18656, 14903, 1957, 35308, 13, 340, 20697, 13884, 1393, 45075, 1957, 6134, 4439, 40362, 13, 14513, 1296, 14510, 340, 2421, 6868, 28459, 12539, 787, 835, 14450, 13, 20697, 24952, 27518, 779, 27482, 14450, 484, 1494, 12498, 41712, 13]
# <|endoftext|> 50256 None
# ...

# %%
! python 1a_get_token_surprisals.py --inputf sentence_file_contentwords_bypassages.txt --outputf token_surprisals_sentence_file_contentwords_bypassages.txt
# Out:
# beekeeping encourages conservation local habitats. it beekeeper interest conserve local plants produce pollen. passive form agriculture it require native vegetation cleared make way crops. beekeepers also discourage use pesticides crops they kill honeybees.
# ['<|endoftext|>', 'Ġbee', 'keeping', 'Ġencourages', 'Ġconservation', 'Ġlocal', 'Ġhabitats', '.', 'Ġit', 'Ġbee', 'keeper', 'Ġinterest', 'Ġconserve', 'Ġlocal', 'Ġplants', 'Ġproduce', 'Ġpollen', '.', 'Ġpassive', 'Ġform', 'Ġagriculture', 'Ġit', 'Ġrequire', 'Ġnative', 'Ġvegetation', 'Ġcleared', 'Ġmake', 'Ġway', 'Ġcrops', '.', 'Ġbee', 'keepers', 'Ġalso', 'Ġdiscourage', 'Ġuse', 'Ġpesticides', 'Ġcrops', 'Ġthey', 'Ġkill', 'Ġhoney', 'bees', '.']
# [50256, 20697, 19934, 18656, 14903, 1957, 35308, 13, 340, 20697, 13884, 1393, 45075, 1957, 6134, 4439, 40362, 13, 14513, 1296, 14510, 340, 2421, 6868, 28459, 12539, 787, 835, 14450, 13, 20697, 24952, 635, 27518, 779, 27482, 14450, 484, 1494, 12498, 41712, 13]
# <|endoftext|> 50256 None
# ...

# %%
# already run:

# %%
! python 1a_get_token_surprisals.py --inputf sentence_file_Original_bypassages.txt --outputf token_surprisals_sentence_file_Original_bypassages.txt
# Out:
# beekeeping encourages the conservation of local habitats. it is in every beekeeper's interest to conserve local plants that produce pollen. as a passive form of agriculture it does not require that native vegetation be cleared to make way for crops. beekeepers also discourage the use of pesticides on crops because they could kill the honeybees.
# ['<|endoftext|>', 'Ġbee', 'keeping', 'Ġencourages', 'Ġthe', 'Ġconservation', 'Ġof', 'Ġlocal', 'Ġhabitats', '.', 'Ġit', 'Ġis', 'Ġin', 'Ġevery', 'Ġbee', 'keeper', "'s", 'Ġinterest', 'Ġto', 'Ġconserve', 'Ġlocal', 'Ġplants', 'Ġthat', 'Ġproduce', 'Ġpollen', '.', 'Ġas', 'Ġa', 'Ġpassive', 'Ġform', 'Ġof', 'Ġagriculture', 'Ġit', 'Ġdoes', 'Ġnot', 'Ġrequire', 'Ġthat', 'Ġnative', 'Ġvegetation', 'Ġbe', 'Ġcleared', 'Ġto', 'Ġmake', 'Ġway', 'Ġfor', 'Ġcrops', '.', 'Ġbee', 'keepers', 'Ġalso', 'Ġdiscourage', 'Ġthe', 'Ġuse', 'Ġof', 'Ġpesticides', 'Ġon', 'Ġcrops', 'Ġbecause', 'Ġthey', 'Ġcould', 'Ġkill', 'Ġthe', 'Ġhoney', 'bees', '.']
# ...

# %%
! python 1a_get_token_surprisals.py --inputf sentence_file_nouns_bypassages.txt --outputf token_surprisals_sentence_file_nouns_bypassages.txt
# Out:
# beekeeping conservation habitats. it beekeeper interest plants pollen. form agriculture it vegetation way crops. beekeepers use pesticides crops they honeybees.
# ['<|endoftext|>', 'Ġbee', 'keeping', 'Ġconservation', 'Ġhabitats', '.', 'Ġit', 'Ġbee', 'keeper', 'Ġinterest', 'Ġplants', 'Ġpollen', '.', 'Ġform', 'Ġagriculture', 'Ġit', 'Ġvegetation', 'Ġway', 'Ġcrops', '.', 'Ġbee', 'keepers', 'Ġuse', 'Ġpesticides', 'Ġcrops', 'Ġthey', 'Ġhoney', 'bees', '.']
# [50256, 20697, 19934, 14903, 35308, 13, 340, 20697, 13884, 1393, 6134, 40362, 13, 1296, 14510, 340, 28459, 835, 14450, 13, 20697, 24952, 779, 27482, 14450, 484, 12498, 41712, 13]
# <|endoftext|> 50256 None
# Ġbee 20697 tensor([ -7.3203,  -3.7250,  -6.9545,  ..., -17.9763, -18.2337,  -6.2530])
# keeping 19934 tensor([ -6.9691,  -8.0152,  -9.3033,  ..., -12.5827, -13.6839,  -8.7327])
# Ġconservation 14903 tensor([ -6.6532,  -7.5854, -10.8470,  ..., -13.2976, -16.5380,  -6.9695])
# ...

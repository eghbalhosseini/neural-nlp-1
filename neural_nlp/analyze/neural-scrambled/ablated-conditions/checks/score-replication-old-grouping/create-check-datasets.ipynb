# %%
import pickle
import os

from neural_nlp.benchmarks.neural import *
from neural_nlp.models import *
import neural_nlp
from neural_nlp.models.implementations import *
from neural_nlp.stimuli import StimulusSet
import xarray as xr

benchmark_pool = [
    ('Pereira2018-encoding', PereiraEncoding),
    ('Pereira2018-encoding-scrambled-original', PereiraEncodingScrambledOriginal),
]

benchmark_pool = {identifier: LazyLoad(lambda identifier=identifier, ctr=ctr: ctr(identifier=identifier))
                  for identifier, ctr in benchmark_pool}

# fetch stimulus set
benchmark_test = benchmark_pool['Pereira2018-encoding']
stimuli_df = benchmark_test._target_assembly.attrs['stimulus_set']
stimuli_df
# Out:
#                                               sentence  sentence_num  \
# 0    Beekeeping encourages the conservation of loca...             0
# 1    It is in every beekeeper's interest to conserv...             1
# 2    As a passive form of agriculture, it does not ...             2
# 3    Beekeepers also discourage the use of pesticid...             3
# 4    Artisanal beekeepers go to extremes for their ...             4
# ..                                                 ...           ...
# 622  Some windows have multiple panes to increase i...           379
# 623                   A woman is a female human adult.           380
# 624    A woman is stereotypically seen as a caregiver.           381
# 625     A woman can become pregnant and bear children.           382
# 626  A woman has different reproductive organs than...           383
#
#           stimulus_id    experiment                       story  \
# 0      243sentences.0  243sentences     243sentences.beekeeping
# ...

# %%
sentences = list(stimuli_df["sentence"])

import re

no_punctuation_sentences = [re.sub(r'[^\w\s\'\-]','',sentences[i]) for i in range(len(sentences))]
no_punctuation_sentences

# #test functionality
# for i in range(10):
#     print(sentences[i])
#     print(re.sub(r'[^\w\s\'\-]','',sentences[i])) #remove everything except words and space
#     print("\n")
# Out:
# ['Beekeeping encourages the conservation of local habitats',
#  "It is in every beekeeper's interest to conserve local plants that produce pollen",
#  'As a passive form of agriculture it does not require that native vegetation be cleared to make way for crops',
#  'Beekeepers also discourage the use of pesticides on crops because they could kill the honeybees',
#  'Artisanal beekeepers go to extremes for their craft but their product is worth the effort',
#  'Artisanal honey-making emphasizes quality and character over quantity and consistency',
#  'To produce the finest honey beekeepers become micromanagers of their honeybees',
#  'They scout the fields know when nectar flows and select the best ways to extract honey',
#  'As the beekeeper opens the hive the deep hum of 40000 bees fills the air',
#  'The beekeeper checks honey stores pollen supplies and the bee nursery',
#  "Bees crawl across his bare arms and hands but they don't sting because they're gentle",
# ...

# %%
no_punctuation_df = stimuli_df.copy()
no_punctuation_df["sentence"] = no_punctuation_sentences

savedir = '/om/user/ckauf/neural-nlp/ressources/scrambled-stimuli-dfs'
fname = f'stimuli_nopunctuation.pkl'
with open(os.path.join(savedir, fname), 'wb') as fout:
    pickle.dump(no_punctuation_df, fout)
no_punctuation_df
# Out:
#                                               sentence  sentence_num  \
# 0    Beekeeping encourages the conservation of loca...             0
# 1    It is in every beekeeper's interest to conserv...             1
# 2    As a passive form of agriculture it does not r...             2
# 3    Beekeepers also discourage the use of pesticid...             3
# 4    Artisanal beekeepers go to extremes for their ...             4
# ..                                                 ...           ...
# 622  Some windows have multiple panes to increase i...           379
# 623                    A woman is a female human adult           380
# 624     A woman is stereotypically seen as a caregiver           381
# 625      A woman can become pregnant and bear children           382
# 626  A woman has different reproductive organs than...           383
#
#           stimulus_id    experiment                       story  \
# 0      243sentences.0  243sentences     243sentences.beekeeping
# ...

# %%
with open(os.path.join(savedir, "stimuli_lowPMI.pkl"), 'rb') as f:
    lowpmi_df = pickle.load(f)
    
lowpmi_sentences = list(lowpmi_df["sentence"])
lowpmi_finalperiod = [elm + "." for elm in lowpmi_sentences]

lowpmi_finalperiod_df = stimuli_df.copy()
lowpmi_finalperiod_df["sentence"] = lowpmi_sentences

savedir = '/om/user/ckauf/neural-nlp/ressources/scrambled-stimuli-dfs'
fname = f'stimuli_lowpmi_finalperiod.pkl'
with open(os.path.join(savedir, fname), 'wb') as fout:
    pickle.dump(lowpmi_finalperiod_df, fout)
lowpmi_finalperiod_df
# Out:
#                                               sentence  sentence_num  \
# 0    beekeeping conservation habitats the of encour...             0
# 1    is interest local produce it every that in to ...             1
# 2    passive agriculture not native be make crops a...             2
# 3    beekeepers discourage pesticides kill the on t...             3
# 4    artisanal go craft is to their their the for b...             4
# ..                                                 ...           ...
# 622  windows multiple increase some inside to have ...           379
# 623                    woman female adult a a is human           380
# 624     woman stereotypically caregiver a a as is seen           381
# 625      woman pregnant children a and can become bear           382
# 626  woman different organs a a than has reproducti...           383
#
#           stimulus_id    experiment                       story  \
# 0      243sentences.0  243sentences     243sentences.beekeeping
# ...

# %% [markdown]
# ### Old checks for stimulus set name below. Fixed now

# %%
benchmark_test._target_assembly.attrs.keys()
# Out:
# odict_keys(['version', 'stimulus_set', 'class_module', 'class_name', 'stimulus_set_name'])

# %%
print(benchmark_test._target_assembly.attrs["stimulus_set_name"])
print(benchmark_test._target_assembly.attrs["stimulus_set"].name)
# Out:
# Pereira2018
# Pereira2018

# %%
# fetch stimulus set
benchmark_test2 = benchmark_pool['Pereira2018-encoding-scrambled-original']
stimuli_df2 = benchmark_test2._target_assembly.attrs['stimulus_set']
print(benchmark_test2._target_assembly.attrs["stimulus_set_name"])
print(benchmark_test2._target_assembly.attrs["stimulus_set"].name)
# Out:
# /om/user/ckauf/.conda/envs/brainmodeling/lib/python3.6/site-packages/brainio_base/assemblies.py:213: FutureWarning: The inplace argument has been deprecated and will be removed in a future version of xarray.
#   xr_data.set_index(append=True, inplace=True, **coords_d)
# Pereira2018
# Pereira2018-Original-lasttoken

# %%
benchmark_test2._target_assembly.attrs["class_module"]
# Out:
# 'brainio_base.assemblies'

# %%
benchmark_test2._target_assembly.attrs["class_name"]
# Out:
# 'NeuroidAssembly'

# %% [markdown]
# #### Stimulus set name doesn't get stored properly >> problem?
# https://github.com/mschrimpf/neural-nlp/blob/d370adca7d6dc45c196ad4ceda1bbfa39dc11989/neural_nlp/analyze/data/store_s3.py#L42
#
# if 'stimulus_set' in assembly.attrs:
#
#         assembly.attrs['stimulus_set_name'] = assembly.attrs['stimulus_set'].name
#
# #### I don't think it is, the correct sentences are being listened to for the activation extraction and the neural data is supposed to stay the same. I changed it such that the name is the same now though.
# > neural.py line 501

# %%
benchmark_test3 = benchmark_pool['Pereira2018-encoding-ablation-contentwords']
benchmark_test3._target_assembly.attrs["stimulus_set_name"]
# Out:
# /om/user/ckauf/.conda/envs/brainmodeling/lib/python3.6/site-packages/brainio_base/assemblies.py:213: FutureWarning: The inplace argument has been deprecated and will be removed in a future version of xarray.
#   xr_data.set_index(append=True, inplace=True, **coords_d)
# 'Pereira2018'

# %%
benchmark_test3._target_assembly.attrs["stimulus_set"].name
# Out:
# 'Pereira2018-contentwords-lasttoken'

# %%
#Used here in fMRI script: https://github.com/mschrimpf/neural-nlp/blob/d370adca7d6dc45c196ad4ceda1bbfa39dc11989/neural_nlp/neural_data/fmri.py#L248
